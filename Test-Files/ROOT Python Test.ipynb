# %%
#!/usr/bin/env python
from ROOT import TH1D, TCanvas, TF1
from ROOT import gStyle
from numpy.random import normal

num = 100000
mean = 5.0
sigma = 1.0

hist = TH1D("hist", "Gaussian", 100, 0.0, 10.0)
c1 = TCanvas('c1', 'Python Example', 200, 10, 700, 500)
gStyle.SetOptStat(111)
gStyle.SetOptFit(111)

throw = normal(loc=mean, scale=sigma, size=num)
[hist.Fill(t) for t in throw]

c1.cd()
hist.Draw()
hist.Fit("gaus")

c1.Draw()
# Out:
#  FCN=73.4311 FROM MIGRAD    STATUS=CONVERGED      51 CALLS          52 TOTAL
#                      EDM=6.84198e-07    STRATEGY= 1      ERROR MATRIX ACCURATE
#   EXT PARAMETER                                   STEP         FIRST
#   NO.   NAME      VALUE            ERROR          SIZE      DERIVATIVE
#    1  Constant     3.98478e+03   1.54609e+01   5.31022e-02  -5.76585e-06
#    2  Mean         5.00130e+00   3.16653e-03   1.33385e-05   3.68077e-01
#    3  Sigma        1.00048e+00   2.24940e-03   2.57295e-06  -1.42235e-01
# Warning in <TROOT::Append>: Replacing existing TH1: hist (Potential memory leak).
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c1
